# %% [markdown]
# <a href="https://colab.research.google.com/github/SANTIAGO13LOZANO/ANGULARANIMALS/blob/main/Transfer_Learning_Emociones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/datas/Nervioso.zip
# !rm -rf /content/data/Feliz.zip
# !rm -rf /content/data/Cansado.zip
# !rm -rf /content/data/aburrido.zip
# !rm -rf /content/data/Triste.zip

# %%
# !unzip /content/Feliz.zip -d /content/dataset/
# Out:
# Archive:  /content/Feliz.zip
#   inflating: /content/dataset/Feliz/65c27d24da9df.jpeg
#   inflating: /content/dataset/Feliz/769933690_233804290_1706x960.webp
#   inflating: /content/dataset/Feliz/8-cosas-que-las-personas-felices-nunca-hacen_x2.jpg
#   inflating: /content/dataset/Feliz/cual-es-el-camino-para-ser-personas-felices-5462-mainImage-2.jpg
#   inflating: /content/dataset/Feliz/download.jpeg
#   inflating: /content/dataset/Feliz/feliz3.jpg
#   inflating: /content/dataset/Feliz/images.jpeg
#   inflating: /content/dataset/Feliz/michael-dam-258165-unsplash_WEB2.jpg
#   inflating: /content/dataset/Feliz/seguros-sura-10-habitos-de-las-personas-felices-mini.jpg
#   inflating: /content/dataset/Feliz/shutterstock-1114627214_12908101_20191227104054-focus-0-0-375-240.jpg

# %%
# !unzip /content/Cansado.zip -d /content/dataset/
# Out:
# Archive:  /content/Cansado.zip
#   inflating: /content/dataset/Cansado/depositphotos_75056543-stock-photo-boring-man-portrait.jpg
#   inflating: /content/dataset/Cansado/depositphotos_78331218-stock-photo-depressed-woman.jpg
#   inflating: /content/dataset/Cansado/f.elconfidencial.com_original_910_bbd_72d_910bbd72ddab956186c2522fcb781e8f.jpg
#   inflating: /content/dataset/Cansado/hombre-cansado-trabajando-tarde-oficina_23-2149006179.avif
#   inflating: /content/dataset/Cansado/images.jpeg
#   inflating: /content/dataset/Cansado/linda-mujer-expresion-sueno-aspecto-cansado-sosteniendo-su-mano-mejilla-cerrando-ojos-cansancio_273609-7716.avif
#   inflating: /content/dataset/Cansado/sdasd.jpeg

# %%
# !unzip /content/Nervioso.zip -d /content/dataset/
# Out:
# Archive:  /content/Nervioso.zip
#   inflating: /content/dataset/Nervioso/5fa2f9bb99a6f.jpeg
#  extracting: /content/dataset/Nervioso/ansiedad_nerviosa_sintomas_psicologicos_46490_3_600.webp
#   inflating: /content/dataset/Nervioso/depositphotos_63717627-stock-photo-shy-unhappy-guy-with-black.jpg
#   inflating: /content/dataset/Nervioso/EF6FDWFUQZDXFFOG473QGZBKNA.avif
#   inflating: /content/dataset/Nervioso/images.jpeg
#   inflating: /content/dataset/Nervioso/por_que_siempre_estoy_tan_nerviosa_3741_orig.jpg
#   inflating: /content/dataset/Nervioso/retrato-muchacha-estudiante-que-sienta-escritorio-que-muerde-su-puno_1163-2568.avif
#   inflating: /content/dataset/Nervioso/sintomas_y_tratamiento_de_la_ansiedad_nerviosa_46490_orig.jpg

# %%
# !unzip /content/Triste.zip -d /content/dataset/
# Out:
# Archive:  /content/Triste.zip
#   inflating: /content/dataset/Triste/5fa3d896bec2a.jpeg
#   inflating: /content/dataset/Triste/82042341-personas-dolor-y-concepto-de-violencia-domВstica-cerca-de-triste-mujer-llorando.jpg
#   inflating: /content/dataset/Triste/captura-de-pantalla-2014-09-28-a-las-13-40-20.png
#  extracting: /content/dataset/Triste/caucasian-sad-woman-sitting-sofa-260nw-2215423007.webp
#   inflating: /content/dataset/Triste/como-ayudar-a-una-que-esta-persona-triste-o-a-ti-mismoa-11-metodos-para-animarse-0_ai1.webp
#   inflating: /content/dataset/Triste/cualquier-tipo-depresioncontribuye-al-aislamiento.webp
#   inflating: /content/dataset/Triste/images.jpeg
#   inflating: /content/dataset/Triste/personas-tristes.jpg
#  extracting: /content/dataset/Triste/tristeza.webp

# %%
# !unzip /content/aburrido.zip -d /content/dataset/
# Out:
# Archive:  /content/aburrido.zip
#   inflating: /content/dataset/aburrido/_124313230_capture.png
#   inflating: /content/dataset/aburrido/1648808301903.jpg
#   inflating: /content/dataset/aburrido/623d477939f87.jpeg
#   inflating: /content/dataset/aburrido/98.webp
#   inflating: /content/dataset/aburrido/aburrimiento_98.webp
#   inflating: /content/dataset/aburrido/f.elconfidencial.com_original_5c5_4b8_106_5c54b81069834f8aa2a8bf74b2ea1d94.jpg
#   inflating: /content/dataset/aburrido/fotonoticia_20220326085953_1200.jpg
#   inflating: /content/dataset/aburrido/images.jpeg
#   inflating: /content/dataset/aburrido/main-qimg-6a55b7951f548629ecca30a615effe88.jpeg
#   inflating: /content/dataset/aburrido/new-work-kolumne-business-karriere-ueberqualifiziert-aufm.webp

# %%
# !ls /content/dataset/Cansado | wc -l #475
# !ls /content/dataset/Feliz | wc -l #515
# !ls /content/dataset/Nervioso | wc -l #475
# !ls /content/dataset/Triste | wc -l #515
# !ls /content/dataset/aburrido | wc -l #475
# Out:
# 7
# 10
# 8
# 9
# 10

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/dataset/Feliz'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/dataset/Triste'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/dataset/aburrido'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/dataset/Nervioso'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-54-b38a69529fc7> in <cell line: 10>()
#      10 for i, nombreimg in enumerate(imagenes[:25]):
#      11   plt.subplot(5,5,i+1)
# ---> 12   imagen = mpimg.imread(carpeta + '/' + nombreimg)
#      13   plt.imshow(imagen)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# -> 1563     with img_open(fname) as image:
#    1564         return (_pil_png_to_float_array(image)
#    1565                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# ...

# %%
import shutil

# %%
# !ls /content/dataset4/llorando | wc -l
# !ls /content/dataset4/estresados | wc -l
# Out:
# ls: cannot access '/content/dataset4/llorando': No such file or directory
# 0
# ls: cannot access '/content/dataset4/estresados': No such file or directory
# 0

# %%
# !ls -la /content/dataset4/
# Out:
# ls: cannot access '/content/dataset4/': No such file or directory

# %%
# !rm /content/dataset4/.ipynb_checkpoints/ -r
# Out:
# rm: cannot remove '/content/dataset4/.ipynb_checkpoints/': No such file or directory

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    zoom_range = [0.5, 1.5],
    validation_split=0.2
)

data_gen_entrenamiento = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')

for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()
# Out:
# Found 26 images belonging to 5 classes.
# Found 4 images belonging to 5 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-35bd0df7ee23> in <cell line: 19>()
#      19 for imagen, etiqueta in data_gen_entrenamiento:
#      20   for i in range(10):
# ---> 21     plt.subplot(2,5,i+1)
#      22     plt.xticks([])
#      23     plt.yticks([])
#
# NameError: name 'plt' is not defined

# %%
import tensorflow as tf
import tensorflow_hub as hub

url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

# %%
mobilenetv2.trainable = False

# %%
modelo = tf.keras.Sequential([
    mobilenetv2,
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
modelo.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 2)                 2562
#
# ...
# Total params: 2260546 (8.62 MB)
# Trainable params: 2562 (10.01 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
modelo.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
EPOCAS = 20

historial = modelo.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=,
    validation_data=data_gen_pruebas
)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-18-702a63d837b8> in <cell line: 3>()
#       1 EPOCAS = 20
#       2
# ----> 3 historial = modelo.fit(
#       4     data_gen_entrenamiento, epochs=EPOCAS, batch_size=45,
#       5     validation_data=data_gen_pruebas
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ...

# %%
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(5)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-b6ac79a90bd4> in <cell line: 1>()
# ----> 1 acc = historial.history['accuracy']
#       2 val_acc = historial.history['val_accuracy']
#       3
#       4 loss = historial.history['loss']
#       5 val_loss = historial.history['val_loss']
#
# NameError: name 'historial' is not defined

# %%
from PIL import Image
import requests
from io import BytesIO
import cv2

def categorizar(url):
  respuesta = requests.get(url)
  img = Image.open(BytesIO(respuesta.content))
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = modelo_cargado.predict(img.reshape(-1, 224, 224, 3))
  return np.argmax(prediccion[0], axis=-1), prediccion

# %%
url = 'https://arc-anglerfish-arc2-prod-elcomercio.s3.amazonaws.com/public/HAWL642GUZDBHOOXFQF7OEJJSA.jpg'
prediccion = categorizar (url)
print(prediccion)

# %%
modelo.save('mm/modelo_entrenado.h5')

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import load_model

# %%
with tf.keras.utils.custom_object_scope({'KerasLayer': hub.KerasLayer}):
    modelo_cargado = load_model('mm/modelo_entrenado.h5')
